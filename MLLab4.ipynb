# %%
''' 
implementing knn on make_moons dataset using KNeighborsClassifier model all from scikitlearn
preprocessing using standard scaler
knn is prone to curse of dimensionality
knn is also prone to overfitting is k value is too low/high'''

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_moons
x,y = make_moons(n_samples=300, noise=0.3, random_state=42)
df = pd.DataFrame(x,columns=['feature1','feature2'])
df['target']=y
df.head()
# Out:
#    feature1  feature2  target
# 0  0.924865 -0.237611       1
# 1  2.587875 -0.112862       1
# 2 -0.421033  0.447485       1
# 3  0.693145  0.481778       0
# 4  1.190855 -0.525165       1

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='feature1', y='feature2', hue='target', palette='Set1')
plt.title('2D Visualization - Scatter Plot of Feature1 vs Feature2')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y, test_size=0.2, random_state=42, stratify=y)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train, y_train)
y_pred = knn.predict(x_test)

#accuracy
print(f"Test Accuracy (k=5): {accuracy_score(y_test,y_pred):.2f}")
# Out:
# Test Accuracy (k=5): 0.82
